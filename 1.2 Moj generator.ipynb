# %%
skup = ('j','u','r','a',2,5)
l = list(skup)

def permutacije(l):
    if len(l) == 1:
        yield l
    else: 
        for p in permutacije(l[1:]):
            for i in range (len(l)):
                yield p[:i] + l[0:1] + p[i:]

r = permutacije(l)
z = list(r)
print(z)
print(len(z))
# Out:
# [['j', 'u', 'r', 'a', 2, 5], ['u', 'j', 'r', 'a', 2, 5], ['u', 'r', 'j', 'a', 2, 5], ['u', 'r', 'a', 'j', 2, 5], ['u', 'r', 'a', 2, 'j', 5], ['u', 'r', 'a', 2, 5, 'j'], ['j', 'r', 'u', 'a', 2, 5], ['r', 'j', 'u', 'a', 2, 5], ['r', 'u', 'j', 'a', 2, 5], ['r', 'u', 'a', 'j', 2, 5], ['r', 'u', 'a', 2, 'j', 5], ['r', 'u', 'a', 2, 5, 'j'], ['j', 'r', 'a', 'u', 2, 5], ['r', 'j', 'a', 'u', 2, 5], ['r', 'a', 'j', 'u', 2, 5], ['r', 'a', 'u', 'j', 2, 5], ['r', 'a', 'u', 2, 'j', 5], ['r', 'a', 'u', 2, 5, 'j'], ['j', 'r', 'a', 2, 'u', 5], ['r', 'j', 'a', 2, 'u', 5], ['r', 'a', 'j', 2, 'u', 5], ['r', 'a', 2, 'j', 'u', 5], ['r', 'a', 2, 'u', 'j', 5], ['r', 'a', 2, 'u', 5, 'j'], ['j', 'r', 'a', 2, 5, 'u'], ['r', 'j', 'a', 2, 5, 'u'], ['r', 'a', 'j', 2, 5, 'u'], ['r', 'a', 2, 'j', 5, 'u'], ['r', 'a', 2, 5, 'j', 'u'], ['r', 'a', 2, 5, 'u', 'j'], ['j', 'u', 'a', 'r', 2, 5], ['u', 'j', 'a', 'r', 2, 5], ['u', 'a', 'j', 'r', 2, 5], ['u', 'a', 'r', 'j', 2, 5], ['u', 'a', 'r', 2, 'j', 5], ['u', 'a', 'r', 2
# ...
